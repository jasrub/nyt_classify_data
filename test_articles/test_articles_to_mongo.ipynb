# %%
import os
import sys
from bs4 import BeautifulSoup
import pymongo
import datetime
import urllib2
import json

# %%
def get_full_text(url):
    try:
        opener = urllib2.build_opener(urllib2.HTTPCookieProcessor())
        response = opener.open(url)
        html = response.read()
        soup = BeautifulSoup(html, 'html.parser')
        story_contet = soup.find_all('p', { "class" : "story-content" })
        return ' '.join([s.string for s in story_contet if s.string])
    except:
        return None

# %%
def article_to_doc(article):
    doc = {}
    doc['_id'] = article['_id']
    full_text = get_full_text(article['web_url'])
    if not full_text:
        print article['web_url']
        return None
    doc['full_text'] = full_text
    if article['abstract'] is not None:
        doc['abstract'] = article['abstract'].encode("utf8")
    doc['headline'] = article['headline']['main'].encode("utf8")
    doc['desk'] = article['news_desk']
    doc['date'] = article['pub_date'] # cutting time of day.
    try:
        date_object = datetime.datetime.strptime(article['pub_date'], '%Y-%m-%dT%H:%M:%SZ')
        doc["ISODate"] = date_object
    except ValueError as e:
        try:
            date_object = datetime.datetime.strptime(article['pub_date'], '%Y-%m-%dT%H:%M:%S+0000')
            doc["ISODate"] = date_object
        except:
            print "no ISO date id: %d"%doc["_id"]
    doc['section'] = article['section_name']
    doc['subsection'] = article['subsection_name']
    if article['snippet'] is not None:
        doc['snippet'] = article['snippet'].encode("utf8")
    doc['source'] = article['source']
    doc['types_of_material'] = article['type_of_material']
    doc['url'] = article['web_url']
    doc['word_count'] = article['word_count']
    # locations
    locations = []
    for x in range(0,len(article['keywords'])):
        if 'glocations' in article['keywords'][x]['name']:
            locations.append(article['keywords'][x]['value'])
    doc['locations'] = locations
    # subject
    subjects = []
    for x in range(0,len(article['keywords'])):
        if 'subject' in article['keywords'][x]['name']:
            subjects.append(article['keywords'][x]['value'])
    doc['descriptors'] = subjects   
    return doc

# %%
docs = []

# %%
articles = []
with open ('articles.json', 'r') as f:
    articles = json.load(f)

# %%
client = pymongo.MongoClient('mongodb://um.media.mit.edu:27017/super-glue')
db = client.nyt_corpus
articles_collection = db.test_articles

# %%
added = False
for i, article in enumerate(articles):
    if articles_collection.find({"_id": article["_id"]}).count()==0:
        if not added:
            print "starting to add!"
            added = True
        doc = article_to_doc(article)
        if doc:
            articles_collection.insert_one(doc)
            docs.append(doc)
        else:
            print i
# Out:
# starting to add!
# http://www.nytimes.com/1999/01/03/travel/deep-in-africa-a-most-civilized-discovery.html
# 2306
# http://www.nytimes.com/1995/04/30/nyregion/where-training-awaits-students-in-need.html
# 2308
# http://www.nytimes.com/1993/08/29/nyregion/when-wooded-trail-and-stream-beckon.html
# 2309
# http://www.nytimes.com/1993/05/23/nyregion/yale-student-immortalizes-his-friends-from-the-soup-kitchen.html
# 2310
# http://www.nytimes.com/1993/04/18/nyregion/when-baby-makes-a-lot-more-than-3.html
# 2311
# http://www.nytimes.com/1992/09/27/nyregion/young-artists-draw-on-their-resources.html
# 2312
# http://www.nytimes.com/1991/10/20/nyregion/welcoming-japanese-companies-east-meets-west-at-bottom-line.html
# 2313
# http://www.nytimes.com/1995/08/06/nyregion/view-voluntown-forest-clear-water-camping-pachaug-hopeville-pond.html
# 2314
# 3098
# http://query.nytimes.com/gst/fullpage.html?res=9C0DE4DD133EF934A1575BC0A9609C8B63
# 3099
# http://query.nytimes.com/gst/fullpage.html?res=9402E3DA133EF934A1575BC0A9609C8B63
# 3100
# http://query.nytimes.com/gst/fullpage.html?res=9807E7D9133EF934A1575BC0A9609C8B63
# 3101
# http://query.nytimes.com/gst/fullpage.html?res=9F05E0DC1230F937A35754C0A9609C8B63
# 3103
# http://query.nytimes.com/gst/fullpage.html?res=9406E3D61730F93BA15755C0A9609C8B63
# 3104
# http://query.nytimes.com/gst/fullpage.html?res=9C0DEED7143FF934A25752C0A9609C8B63
# 3111
# http://query.nytimes.com/gst/fullpage.html?res=9804E1D61131F932A25751C1A9639C8B63
# 3118
# http://query.nytimes.com/gst/fullpage.html?res=9903E3DE1E31F936A2575AC0A9639C8B63
# 3122
# http://query.nytimes.com/gst/fullpage.html?res=9507E7DC143EF937A15752C1A9629C8B63
# 3150
# http://query.nytimes.com/gst/fullpage.html?res=9F04E1DB153BF93BA35753C1A9629C8B63
# 3153
# http://query.nytimes.com/gst/fullpage.html?res=940DE2D81439F933A1575AC0A9629C8B63
# 3154
# http://www.nytimes.com/1991/09/03/arts/into-an-age-of-fake-art-a-very-real-quandary.html
# 3310
# http://www.nytimes.com/1991/08/19/business/upheaval-at-salomon-surprise-and-questions-on-treasury-s-retreat.html
# 3311
# http://www.nytimes.com/1991/07/30/business/the-media-business-group-president-named-for-simon-schuster.html
# 3312
# http://www.nytimes.com/1991/07/24/books/book-notes-985891.html
# 3313
# http://www.nytimes.com/1991/06/30/business/profits-dick-snyder-s-ugly-word.html
# 3314
# http://www.nytimes.com/1991/06/28/us/renewal-of-brain-is-found-in-disputed-monkey-tests.html
# 3315
# http://www.nytimes.com/1991/04/08/business/the-media-business-los-angeles-times-revamps-magazine-in-a-bid-for-ads.html
# 3316
# http://www.nytimes.com/1991/02/23/arts/critic-s-notebook-an-excess-of-excess-but-what-a-party.html
# 3317
# http://www.nytimes.com/1991/02/17/realestate/postings-neo-georgian-at-65th-madison-avenue-facelift.html
# 3318
# http://www.nytimes.com/1991/02/17/realestate/streetscapes-the-miller-highway-razed-or-rebuilt-it-s-a-lost-cause.html
# 3319
# http://www.nytimes.com/1991/02/15/arts/guggenheim-may-sue-for-chagall-court-says.html
# 3320
# http://www.nytimes.com/1991/02/04/business/few-bidders-are-expected-in-bank-sale.html
# 3321
# http://www.nytimes.com/1991/01/09/arts/deal-on-stolen-german-art-meets-with-mixed-reaction.html
# 3322
# http://www.nytimes.com/1991/01/06/magazine/child-of-the-movies.html
# 3323
# http://www.nytimes.com/1990/11/04/nyregion/man-arrested-as-police-find-stolen-painting.html
# 3324
# http://www.nytimes.com/1990/10/28/nyregion/the-news-strike-shows-shifting-labor-relations.html
# 3325
# http://www.nytimes.com/1990/10/26/books/bar-gathering-quotations-marx-groucho-musmanno-profession.html
# 3326
# http://www.nytimes.com/1990/10/26/arts/art-dealer-told-again-to-return-mosaics.html
# 3327
# http://www.nytimes.com/1984/05/06/style/robin-bierstedt-lawyer-for-time-weds-pj-mayer.html
# 3393
# http://www.nytimes.com/2010/10/03/t-magazine/03remix-dec-alessi-t-.html
# 3400
# http://www.nytimes.com/2010/10/20/sports/baseball/20yankees.html
# 3404
# http://www.nytimes.com/2010/10/20/nyregion/20textbooks.html
# 3424
# http://www.nytimes.com/2010/10/20/us/politics/20race.html
# 3432
# http://www.nytimes.com/2010/10/20/dining/20Harvard.html
# 3460
# http://www.nytimes.com/2010/10/20/us/politics/20thomas.html
# 3468
# http://www.nytimes.com/2010/10/20/health/20hormone.html
# 3478
# http://www.nytimes.com/2010/10/19/nyregion/19poll.html
# 3494
# http://www.nytimes.com/2010/10/19/business/19flier.html
# 3514
# http://www.nytimes.com/2010/10/19/science/19aspen.html
# 3517
# http://www.nytimes.com/2010/10/19/health/19brody.html
# 3545
# http://www.nytimes.com/2010/10/18/us/18weekahead.html
# 3574
# http://www.nytimes.com/2010/10/18/business/18advantage.html
# 3578

# %%
docs = []
db_articles = articles_collection.find({})
for doc in db_articles:
    docs.append(doc)

# %%
sorted_by_date = sorted(docs, key=lambda k: k['ISODate'])

# %%
sorted_by_date[2100]
# Out:
# {u'ISODate': datetime.datetime(2016, 12, 16, 11, 0, 1),
#  u'_id': u'5853c93b7c459f2525d12393',
#  u'date': u'2016-12-16T11:00:01+0000',
#  u'descriptors': [u'Gifts',
#   u'Families and Family Life',
#   u'Christmas',
#   u'Children and Childhood'],
#  u'desk': u'Well',
#  u'full_text': u'I\u2019ve buried my phone at the bottom of my purse so I can try to ignore the calls, emails and texts from well-meaning relatives, all of whom are asking: Where is the Christmas list? They want suggestions for what to give the kids, the more specific the better. If I say, \u201cMaybe a Lego set?\u201d they\u2019ll ask, \u201cWhich one?\u201d I think it\u2019s about longing: to be taken care of, to let someone else do at least part of the planning. I may be an adult, but some part of me still has a child\u2019s desire to wake up, starry-eyed, and find that gifts have materialized under the tree \u2014 surprises chosen with love and obtained in secret, waiting to be opened in wonder. We don\u2019t outgrow that. Then there\u2019s the guilt, of course. I suspect our relatives wouldn\u2019t need ideas for what to give our children if I did a better job of keeping in touch during the rest of the year. If we visited more often \u2014 if I were a better daughter and sister \u2014 they\u2019d know all my kids\u2019 hobbies and wishes, and I would know theirs. (I haven\u2019t asked anyone what to give them this year. I hope they don\u2019t hate their gifts, but I really do enjoy putting a little imagination into it.) This is also a practical matter. To compile an itemized inventory of wished-for things and divvy it up among grandparents and aunts and uncles would require time, of which I have no surplus. Tonight, for example, I have four events to attend \u2014 two optional-but-encouraged work functions, a fund-raiser for my children\u2019s school, and an already rescheduled social gathering. I don\u2019t know if our 13-year-old son\u2019s soccer game will finish in time for the first event or at what point in the evening my husband\u2019s meeting will let out so that he can come home to watch our 10-year-old daughter. I don\u2019t know what anyone\u2019s going to eat for dinner or when, much less what everyone\u2019s getting for Christmas. Where\u2019s the line between writing a letter to the North Pole and forking over an itemized file of material desires? The former seems sweet; the latter feels like handing someone a grocery list. Plus, if you ask only for things you know exist, how will you ever be delighted by something you couldn\u2019t have fathomed? Still, it\u2019s my job as a parent to orchestrate all the steps that make Christmas look like magic, and that means I have to make the decisions. We\u2019re lucky to have family who love our kids, who want to do something nice for them, and I know it\u2019s ungrateful not to return their calls. So I dig the phone out of my purse. \u201cAnything is fine, really,\u201d I try to tell my mom. \u201cThey like everything. Maybe clothes?\u201d \u201cThat doesn\u2019t help me,\u201d she says. That\u2019s when I realize she\u2019s feeling some variation of the same thing I am: Help me. Make this easier, please. Tell me what to do. At the end of the school day, my daughter climbs into the car. Thanks to her brother\u2019s sports schedule, she has done homework on bleachers and back seats for three of the past four nights. \u201cWhat\u2019s for dinner?\u201d she asks. \u201cI\u2019m not sure yet,\u201d I say. \u201cWhat are you in the mood for?\u201d \u201cWhatever,\u201d she says. \u201cYou pick.\u201d She wants me to decide. I want someone else to decide. My mother wants me to decide. We don\u2019t grow out of this either, apparently. I make a decision: No events tonight. Not one, not two, not three, not four. I make the calls and beg off. \u201cI\u2019m sorry. I wish I could come.\u201d And it\u2019s true; I wish I could be many places at once. But I can\u2019t. We go to the soccer game. We come home. I make spaghetti. Father and son hang out after homework and talk about whether the deer in our yard have enough to eat when it turns cold. My daughter and I share a blanket on the sofa. She\u2019s braiding the fringe when I ask, \u201cIf Mimi\u201d \u2013 her grandmother \u ...
#  u'headline': u'Wishing Away the Wish List',
#  u'locations': [],
#  u'section': u'Well',
#  u'snippet': u'Some part of me still has a child\u2019s desire to wake up, starry-eyed, and find surprises chosen with love and obtained in secret....',
#  u'source': u'The New York Times',
#  u'subsection': u'Family',
#  u'types_of_material': u'News',
#  u'url': u'http://www.nytimes.com/2016/12/16/well/family/wishing-away-the-wish-list.html',
#  u'word_count': u'956'}

# %%
subjects = set([sub for story in docs for sub in story['descriptors']])

# %%
descriptors = []
desc = {}
with open('../descriptors.json') as data_file:
    desc = json.load(data_file)
    descriptors = [x['word'] for x in desc]

# %%
descriptors.remove("")

# %%
missing = [sub.lower() for sub in list(subjects) if sub.lower() not in descriptors]

# %%
real_missing = []
count= 0
for word in missing:
    found = False
    for desc in descriptors:
        a = word.lower().split()
        b = desc.split()
        if set(a) < set(b) or set(b) < set(a):
            print "%s  --  %s"%(word, desc)
            found=True
#     print found
    if found:
        count+=1
    else:
        real_missing.append(word)
# Out:
# teenagers and adolescence  --  teenagers
# israeli settlements  --  israeli settlements (occupied territories)
# israeli settlements  --  israeli settlements (occupiedterritories)
# basketball (college)  --  basketball
# world trade center (manhattan, ny)  --  world trade center
# labor and jobs  --  labor
# history (academic subject)  --  history
# united nations framework convention on climate change  --  climate
# united nations framework convention on climate change  --  united nations
# memorabilia and souvenirs  --  memorabilia
# memorabilia and souvenirs  --  souvenirs
# greenhouse gas emissions  --  gas
# citizenship and naturalization  --  citizenship
# same-sex marriage, civil unions and domestic partnerships  --  partnerships
# middle east and africa migrant crisis  --  middle east
# bioenergy and biofuels  --  biofuels
# nuclear weapons  --  rocky flats nuclear weapons plant (colo)
# nuclear weapons  --  weapons
# shopping centers and malls  --  shopping centers
# anthropology  --  archaeology and anthropology
# anthropology  --  archeology and anthropology
# embargoes and sanctions  --  sanctions (economic) >>> use embargoes and economic sanctions
# embargoes and sanctions  --  embargoes  and economic sanctions
# culture (arts)  --  culture
# funerals and memorials  --  funerals
# online advertising  --  advertising
# automobile renting and leasing  --  renting and leasing
# automobile renting and leasing  --  leasing
# automobile renting and leasing  --  renting and
# leasing
# two thousand sixteen  --  two thousand
# bars and nightclubs  --  bars
# bars and nightclubs  --  nightclubs
# cold war era  --  cold
# elections, governors  --  governors
# dodd-frank wall street reform and consumer protection act (2010)  --  consumer protection
# voting rights act (1965)  --  voting rights act
# service dogs and other animals  --  animals
# service dogs and other animals  --  dogs
# muslims and islam  --  islam
# medical marijuana  --  marijuana
# television sets and media devices  --  television
# television sets and media devices  --  media
# television sets and media devices  --  television sets
# women and girls  --  women
# women and girls  --  national girls and women in sports day
# polls and public opinion  --  public opinion
# polls and public opinion  --  public
# opinion
# polls and public opinion  --  public  opinion
# civil rights and liberties  --  civil rights
# inflation (economics)  --  inflation
# private equity  --  private investment in public equity (pipe)
# carbon caps and emissions trading programs  --  carbon
# luggage and packing  --  luggage
# real estate and housing (residential)  --  housing
# real estate and housing (residential)  --  real estate
# aviation accidents, safety and disasters  --  disasters
# animal migration  --  migration
# ethics and official misconduct  --  ethics
# prison guards and corrections officers  --  guards
# prison guards and corrections officers  --  corrections
# headphones and headsets  --  headphones
# sports injuries  --  sports
# babies and infants  --  babies
# oceans and seas  --  oceans
# murders, attempted murders and homicides  --  murders and attempted murders
# murders, attempted murders and homicides  --  murders and
# attempted murders
# murders, attempted murders and homicides  --  murders and attempted
# murders
# murders, attempted murders and homicides  --  murders
# and attempted murders
# murders, attempted murders and homicides  --  murders and attempted
# murders
# murders, attempted murders and homicides  --  murders and attempted
# chefs  --  top chefs soup
# interior design and furnishings  --  design
# interior design and furnishings  --  interior design
# interior design and furnishings  --  interior  design
# electronic health records  --  health
# maritime accidents and safety  --  accidents and safety
# maritime accidents and safety  --  accidents and
# safety
# elections, district attorneys  --  district attorneys
# elections, district attorneys  --  district  attorneys
# space and astronomy  --  space
# space and astronomy  --  astronomy
# driverless and semiautonomous vehicles  --  vehicles
# pop and rock music  --  music
# pop and rock music  --  rock music
# credit cards  --  credit
# credit cards  --  credit and money cards
# credit cards  --  credit cards and accounts
# credit cards  --  credit cards and money cards
# credit cards  --  credit cards andaccounts
# credit cards  --  credit cards and accounts > credit and money cards
# series  --  surveys and series
# series  --  world series
# series  --  little league world series
# series  --  college world series
# series  --  world series of poker
# series  --  lincoln center american songbook series
# series  --  surveys and
# series
# series  --  lincoln center great performers series
# series  --  nascar nextel cup series
# series  --  world series of golf
# series  --  tennis masters series
# series  --  nec world series of golf
# series  --  little league softball world series
# series  --  american championship racing series
# series  --  intelligence series
# series  --  middleweight world championships series
# series  --  chevy truck super series
# series  --  children and youth,baseball,playoff games,world series
# series  --  women's global gt series
# series  --  great orchestras of world series
# series  --  baseball,running,playoff games,world series
# series  --  japan series (baseball)
# series  --  harbourfront reading series
# series  --  new works october series (festival)
# series  --  women's college world series
# series  --  open magazine pamphlet series
# series  --  eccentric-american music series
# series  --  nascar craftsman truck series
# series  --  little league junior world series of softball
# series  --  terms not availablegillette declared itself victorious in its proxy fight with coniston partners. but the new york investment firm said it might challenge the outcome. coniston, which owns 5.8 percent of gillette's stock, had sought to elect four directors. gillette said it outpolled coniston, 52 percent to 48 percent.
# [
# page d1.
# ]
# <p>
# texaco filed suit against carl c. icahn, its largest shareholder, seeking to block him from pursuing a proxy battle to elect himself and four associates to the board. texaco said mr. icahn and his associates had used ''deceptive and manipulative means'' to try to make a profit at other shareholders' expense.
# [
# d1.
# ]
# <p>
# the trial of two former bankers ended in a hung jury while a third defendant was acquitted. a mistrial was declared in the trial on fraud charges of a former officer of continental illinois and a former penn square bank vice president.
# [
# d1.
# ]
# <p>
# usg sued merrill lynch for its role in desert partners' hostile tender offer for usg.
# [
# d4.
# ]
# <p>
# xerox introduced a major series of copiers, including a personal copier in the low end of the market.
# [
# d4.
# ]
# <p>
# amdahl introduced mainframes that it said are more powerful than any machines compatible with i.b.m.'s 3090 series.
# [
# d4.
# ]
# the economy
# <p>
# <p>
# discount store executives and consumer advocates complained that a supreme court ruling on monday would encourage some big, traditional merchants to put pressure on manufacturers to stop supplying discounters. but manufacturers doubted that the ruling would have a major impact.
# [
# d1.
# ]
#  sponsors of legislation that would make it easier for discounters to bring price-fixing cases against manufacturers and full-price retailers said the court's decision would probably improve the prospects for their bill.
# [
# d6.
# ]
# <p>
# democrats moved to drop curbs on alaskan oil exports from the trade bill in the face of a threatened presidential veto.
# [
# d2.
# ]
# markets
# <p>
# <p>
# the s.e.c. will consider a plan that could ban all trading in a stock when important news about it is pending. one division supports the ban and another opposes it.
# [
# d1.
# ]
# <p>
# stock prices spurted in late trading, lifting the dow jones industrial average by 15.09 points, to 2,058.36. on the big board, advancing issues outnumbered declining stocks, 897 to 580.
# [
# d8.
# ]
# <p>
# prices of treasury bonds and notes staged a small rally in sleepy trading. activity was light because japanese financial markets were closed for a holiday.
# [
# d16.
# ]
# <p>
# the dollar rose narrowly in the u.s. and fell overseas. gold fell $2.10 on the comex, to $443.50 an ounce.
# [
# d15.
# ]
#  gold futures fell, despite the rally in oil prices.
# [
# d15.
# ]
# international
# <p>
# <p>
# oil prices steadied around the world as spokesmen for several oil-producing nations said they had not abandoned hope of cooperating with opec on steps to reduce output and bolster prices.
# [
# d2.
# ]
#  the saudi decision to block cutbacks drew an angry response from iran in the latest dispute between the two countries.
# [
# a8.
# ]
# technology
# <p>
# <p>
# microelectronics is changing the electric meter, enabling utilities to measure usage more frequently, even on demand.
# [
# d7.
# ]
# <p>
# a chocolate that stays firm at higher temperatures has been developed by a research firm.
# [
# d7.
# ]
# <p>
# a tether to keep champagne corks from flying away is being offered by a san francisco company.
# [
# d7.
# ]
# today's columns
# <p>
# <p>
# mikhail s. gorbachev's attempt to depict his economic changes as a costless fix has left him in a precarious position. peter passell. economic scene.
# [
# d2.
# ]
# <p>
# proponents of ''socially responsible investment'' say investors can prosper financially if they avoid companies whose products or policies violate their moral beliefs. but such investors were not spared the shock of october's market plunge. market place.
# [
# d8.
# ]
# series  --  caribbean world series
# series  --  winter frostbite series
# series  --  tennis master series
# series  --  film comment series (lincoln center)
# series  --  surveysand series
# series  --  fedex championship series (auto racing)
# rana plaza building collapse, bangladesh (2013)  --  building
# car services and livery cabs  --  livery services
# government contracts and procurement  --  contracts
# thai food (cuisine)  --  food
# thai food (cuisine)  --  food food
# illegal immigration  --  immigration
# appraisals and valuation (property)  --  appraisals and valuation
# group homes and supportive housing  --  housing
# rumors and misinformation  --  rumors
# credit scores  --  credit
# world cup 2018 (soccer)  --  world cup (soccer)
# world cup 2018 (soccer)  --  world cup
# public broadcasting  --  reviews
# public broadcasting service (pbs)
# workplace environment  --  environment
# amnesties, commutations and pardons  --  pardons
# football (college)  --  football
# education  --  education and schools
# education  --  special education (handicapped)
# education  --  education (pre-school)
# education  --  bilingual education
# education  --  education (secondary)
# education  --  sex education
# education  --  education (primary)
# education  --  physical education and training
# education  --  adult education
# education  --  drivers education
# education  --  brown v board of education (1954 school integration suit)
# education  --  education andschools
# education  --  education (preschool)
# education  --  quality education act (nj)
# education  --  elementary education
# education  --  drug abuse resistance education (dare)
# education  --  arts education week
# education  --  education enhancement act
# education  --  national security education act of 1991
# education  --  education and schoolsterms not available
# education  --  nutrition labeling and education act of 1990
# education  --  higher education act of 1965
# education  --  teachers and school employees education and schools
# education  --  individuals with disabilities education act
# education  --  board of education (nyc)
# education  --  education and schools,standards and standardization,reading and writing skills
# education  --  education and schools,equal educational opportunities,teachers and school employees,tests and testing
# education  --  federal education of the handicapped act of 1986
# education  --  medicine and health education and schools
# education  --  sex crimes education and schools
# education  --  banks and banking education and schools
# education  --  special
# education (handicapped)
# education  --  education and schoolseducation and schools
# education  --  education
# and schools
# education  --  kesselman, theoodre l, award for arts education
# education  --  juvenile awareness education program
# education  --  lucent technologies center for arts education (newark)
# education  --  privatization education and schools
# gotham independent film awards  --  film
# gotham independent film awards  --  awards
# gotham independent film awards  --  gotham awards
# translation and interpreters  --  translation
# school shootings and armed attacks  --  shootings
# robots and robotics  --  robots
# pop-up stores and restaurants  --  restaurants
# ponzi and pyramid schemes  --  pyramid schemes
# ponzi and pyramid schemes  --  ponzi schemes
# slavery (historical)  --  slavery
# fashion shows  --  shows
# reality television  --  television
# asylum, right of  --  asylum,
# evolution (biology)  --  evolution
# redistricting and reapportionment  --  reapportionment
# monuments and memorials (structures)  --  monuments and memorials
# monuments and memorials (structures)  --  monuments
# monuments and memorials (structures)  --  monuments and
# credit and debt  --  credit
# child pornography  --  pornography
# anxiety and stress  --  anxiety
# book trade and publishing  --  book trade
# mixed martial arts  --  martial arts
# rap and hip-hop  --  havana international hip-hop and rap festival
# elections, state legislature  --  legislature
# immigration detention  --  immigration
# long-term care insurance  --  insurance
# deaths (fatalities)  --  deaths
# arts and antiquities looting  --  looting
# holocaust and the nazi era  --  nazi era
# race and ethnicity  --  race
# cocktails  --  molotov cocktails
# state legislatures  --  legislatures
# pancreatic cancer  --  cancer
# agriculture and farming  --  agriculture
# espionage and intelligence services  --  espionage
# espionage and intelligence services  --  intelligence
# espionage and intelligence services  --  intelligence services
# men and boys  --  men
# middle east and north africa unrest (2010- )  --  middle east
# youth  --  children and youth
# youth  --  youth gangs
# youth  --  million youth march
# youth  --  fountain of youth stakes
# youth  --  childrenand youth
# youth  --  fountain of youth stakes (horse race)
# youth  --  world youth day
# youth  --  children and
# youth
# youth  --  children
# and youth
# youth  --  children and  youth
# youth  --  medicine and health, children and youth
# youth  --  summer youth employment program
# youth  --  world youth chess championships
# youth  --  connecticut ymca youth and government conference
# youth  --  children  and youth
# youth  --  fort apache youth center (nyc)
# youth  --  police department youth olympics
# youth  --  national youth physical fitness championships
# youth  --  muslim youth day
# youth  --  do it your damn self! national youth film and video festival
# youth  --  student and youth travel research institute
# youth  --  united states youth games
# youth  --  crime and criminals,children and youth
# youth  --  fifa world youth championship (soccer)
# youth  --  o'hara invitational youth basketball tournament
# microwaves (electromagnetic waves)  --  microwaves
# bribery and kickbacks  --  bribery
# bribery and kickbacks  --  kickbacks
# free diving  --  diving
# submarines and submersibles  --  submarines
# ratings (audience measurement)  --  ratings
# george washington bridge scandal (2013)  --  george washington bridge
# george washington bridge scandal (2013)  --  bridge
# title ix (gender discrimination legislation)  --  discrimination
# oil sands  --  oil
# supermarkets and grocery stores  --  supermarkets
# supermarkets and grocery stores  --  grocery stores
# capitalism (theory and philosophy)  --  capitalism
# forced labor  --  labor
# japan earthquake and tsunami (2011)  --  japan
# japan earthquake and tsunami (2011)  --  tsunami
# birth rates  --  rates
# symbols  --  signs and symbols
# poaching (wildlife)  --  poaching
# podcasts  --  podcasts and podcasting
# orderliness and clutter  --  clutter
# drug cartels  --  cartels
# careers and professions  --  professions
# gift cards and certificates  --  gift cards
# fantasy sports  --  sports
# biotechnology and bioengineering  --  biotechnology
# conventions, fairs and trade shows  --  trade shows and fairs
# conventions, fairs and trade shows  --  shows
# conventions, fairs and trade shows  --  trade
# shows and fairs
# conventions, fairs and trade shows  --  trade fairs and shows
# housing and real estate  --  housing
# housing and real estate  --  real estate
# elections, mayors  --  mayors
# voice and speech  --  speech
# voice and speech  --  voice
# corporate taxes  --  taxes
# signs and signage  --  signs
# first ladies (us)  --  first ladies
# postal service and post offices  --  postal service
# postal service and post offices  --  offices
# affordable housing  --  housing
# public defenders and court-appointed lawyers (criminal)  --  lawyers
# public defenders and court-appointed lawyers (criminal)  --  public defenders
# food banks and pantries  --  food
# food banks and pantries  --  food food
# real estate (commercial)  --  real estate
# champagne (wine)  --  champagne
# disabilities  --  learning disabilities
# disabilities  --  americans with disabilities act
# disabilities  --  americans with disabilities act of 1990
# disabilities  --  individuals with disabilities education act
# disabilities  --  americans with disabilities act (1991)
# foreign intelligence surveillance act (fisa)  --  intelligence
# civil rights movement (1954-68)  --  civil rights
# tea party movement  --  tea
# transgender and transsexuals  --  transsexuals
# real estate brokers  --  real estate
# hoaxes and pranks  --  hoaxes
# jews and judaism  --  jews
# jews and judaism  --  judaism
# reading and writing skills (education)  --  reading and writing skills
# reading and writing skills (education)  --  reading
# reading and writing skills (education)  --  writing
# treason and sedition  --  treason
# treason and sedition  --  sedition
# 1 world trade center (manhattan, ny)  --  world trade center
# suits and litigation (civil)  --  suits and litigation
# suits and litigation (civil)  --  suits and
# litigation
# suits and litigation (civil)  --  suits
# and litigation
# suits and litigation (civil)  --  suits and  litigation
# disasters and emergencies  --  disasters
# monasteries and monks  --  monasteries
# iraq war (2003- )  --  iraq
# moving and moving industry  --  moving industry
# myths and mythical creatures  --  myths
# voting and voters  --  voting requirements and voters
# generic brands and products  --  generic
# mexican food (cuisine)  --  food
# mexican food (cuisine)  --  food food
# prudential center (newark)  --  prudential center arena (newark)
# college football playoff national championship  --  football
# indecency, obscenity and profanity  --  profanity
# indecency, obscenity and profanity  --  profanity and obscenity
# homosexuality and bisexuality  --  homosexuality
# bourbon (whiskey)  --  bourbon
# kidnapping and hostages  --  kidnapping
# kidnapping and hostages  --  hostages
# income inequality  --  income
# police brutality, misconduct and shootings  --  police
# police brutality, misconduct and shootings  --  shootings
# courts and the judiciary  --  courts
# railroad accidents and safety  --  accidents and safety
# railroad accidents and safety  --  accidents and
# safety
# graduation rates  --  rates
# midterm elections (2014)  --  elections
# fashion and apparel  --  apparel
# breast cancer  --  cancer
# breast cancer  --  breast
# breast cancer  --  world conference on breast cancer
# breast cancer  --  breast and cervical cancer treatment and prevention act
# elderly  --  elderly pharmaceutical insurance coverage
# united states defense and military forces  --  united states
# united states defense and military forces  --  defense and military forces
# united states defense and military forces  --  states
# paid time off  --  time
# great britain withdrawal from eu (brexit)  --  great britain
# explosions (accidental)  --  explosions
# traffic accidents and safety  --  accidents and safety
# traffic accidents and safety  --  accidents and
# safety
# work-life balance  --  balance
# acrostic puzzles  --  puzzles
# iraq war (2003-11)  --  iraq
# factories and manufacturing  --  factories
# evacuations and evacuees  --  evacuations
# executives and management (theory)  --  executives and management
# executives and management (theory)  --  executives  and management
# executives and management (theory)  --  management
# executives and management (theory)  --  executives and
# management
# campaign finance  --  finance
# standard & poor's case-shiller home price index  --  price
# standard & poor's case-shiller home price index  --  index
# coats and jackets  --  coats
# conflicts of interest  --  interest
# copyrights and copyright violations  --  copyrights
# migrant labor (agriculture)  --  labor
# migrant labor (agriculture)  --  migrant labor

# %%
real_missing
# Out:
# [u'afghanistan war (2001-14)',
#  u'segregation and desegregation',
#  u'renminbi (currency)',
#  u'birdwatching',
#  u'deflation (economics)',
#  u'parent-teacher associations',
#  u'e-mail',
#  u'smartphones',
#  u'uefa europa league',
#  u'living wage',
#  u'no child left behind act',
#  u'second avenue subway (nyc)',
#  u'carjacking',
#  u'shipwrecks (historic)',
#  u'cycling, mountain bike',
#  u'arms trade',
#  u'frequent flier programs',
#  u'social networking (internet)',
#  u'parenting',
#  u'roommates',
#  u'red burgundy (wine)',
#  u'offshore drilling and exploration',
#  u'deferred action for childhood arrivals',
#  u'typhoon haiyan (2013)',
#  u'whites',
#  u'paris attacks (november 2015)',
#  u'sustainable living',
#  u'vis-comments',
#  u'organ donation',
#  u'co-working',
#  u'denisova hominid',
#  u'medical devices',
#  u'panama papers',
#  u'graphic novels',
#  u'mortgage-backed securities',
#  u'synthetic cannabinoids',
#  u'3-d devices and effects',
#  u'classified information and state secrets',
#  u'rohingya (ethnic group)',
#  u'british pound (currency)',
#  u'beef',
#  u'hydraulic fracturing',
#  u'online dating',
#  u'performance evaluations (labor)',
#  u'refugees and displaced persons',
#  u'education (k-12)',
#  u'dating and relationships',
#  u'adventure travel',
#  u'vis-dispatch',
#  u'workplace hazards and violations',
#  u'constitution (us)',
#  u'patient protection and affordable care act (2010)',
#  u'boredom',
#  u'logos',
#  u'shopping and retail',
#  u'romani people',
#  u'cocktails and mixed drinks',
#  u'russian illegals program (2010)',
#  u'european sovereign debt crisis (2010- )',
#  u'world heritage sites',
#  u'muslim veiling',
#  u'nama (ethnic group)',
#  u'indigenous people',
#  u'academic and scientific journals',
#  u'cyberattacks and hackers',
#  u'financial planners',
#  u'initial public offerings',
#  u'millennial generation',
#  u'waterboarding',
#  u'herero (ethnic group)',
#  u'e-commerce',
#  u'mobile applications',
#  u'demonstrations, protests, and riots',
#  u'us dollar (currency)',
#  u'family business',
#  u'churches (buildings)',
#  u'municipal bonds',
#  u'data centers',
#  u'web-original programming',
#  u'muay thai',
#  u'addiction (psychology)',
#  u'crowdfunding (internet)',
#  u'targeted killings',
#  u'infrastructure (public works)',
#  u'diplomatic service, embassies and consulates',
#  u'harry potter (fictional character)',
#  u'afghanistan war (2001- )',
#  u'ethicist, the (times column)',
#  u'f-35 airplane',
#  u'uefa champions league (soccer)',
#  u'audio recordings, downloads and streaming',
#  u'indian rupee (currency)',
#  u'paint',
#  u'corruption (institutional)',
#  u'trans-pacific partnership',
#  u'street vendors (non-food)',
#  u'humanitarian aid',
#  u'high net worth individuals',
#  u'speedskating',
#  u'children and childhood',
#  u'sovereign wealth funds',
#  u'vis-photo',
#  u'android (operating system)',
#  u'shareholder rights and activism',
#  u'royal families',
#  u'tests and examinations',
#  u'mobile commerce and payments',
#  u'baby boomers',
#  u'shariah (islamic law)',
#  u'executive compensation',
#  u'instant messaging',
#  u'acthar (drug)',
#  u'white burgundy (wine)',
#  u'banking and financial institutions',
#  u'el nino southern oscillation',
#  u'private spaceflight',
#  u'vows (times column)',
#  u'civilian casualties',
#  u'defectors (political)',
#  u'veganism',
#  u'enterprise computing',
#  u'text messaging',
#  u'antitrust laws and competition issues',
#  u'3-d printers',
#  u'nuclear energy',
#  u'interrogations',
#  u'movies',
#  u'cyberharassment',
#  u'start-ups',
#  u'yen (currency)',
#  u'alternative and renewable energy',
#  u'road trips',
#  u'pregnancy and childbirth',
#  u'gender',
#  u'eco-tourism',
#  u'psychics and fortune tellers',
#  u'detainees',
#  u'commencement speeches',
#  u'racial profiling',
#  u'demonstrations, protests and riots',
#  u'human rights and human rights violations',
#  u'endowments',
#  u'international study and teaching',
#  u'cyberwarfare and defense',
#  u"women's rights",
#  u'cloud computing',
#  u'elder care',
#  u'black friday and cyber monday (shopping)',
#  u'budget travel',
#  u'pancetta',
#  u'wildfires',
#  u'luxury goods and services',
#  u'short-track speedskating',
#  u'modern love (times column)',
#  u'vis-multimedia',
#  u'cheonan (ship)',
#  u'tests (medical)',
#  u'restoration and renovation',
#  u'innovation',
#  u'video recordings, downloads and streaming',
#  u'zika virus',
#  u'native americans',
#  u'data-mining and database marketing',
#  u'child soldiers',
#  u'intellectual disabilities',
#  u'marching bands',
#  u'sprains and strains',
#  u'reservations (airlines, hotels, etc.)',
#  u'gentrification',
#  u'elections, house of representatives',
#  u'september 11 (2001)',
#  u'human trafficking',
#  u'charleston, sc, shooting (2015)',
#  u'hygiene and cleanliness',
#  u'subprime mortgage crisis',
#  u'milan fashion week',
#  u'hotels and travel lodgings',
#  u'elections, senate',
#  u'school discipline (students)',
#  u'for-profit schools',
#  u'street performers',
#  u'federal budget (us)',
#  u'small cars (compact, subcompact and microcars)',
#  u'religion and belief',
#  u'sarbanes-oxley act']

# %%
with open('missing_labels.json' ,'w') as out_file:
    json.dump(real_missing, out_file)

# %%
print "%d / %d"%(count,len(missing))
# Out:
# 209 / 394

# %%
long_desc = [d for d in descriptors if len(d)>90]

# %%
import numpy as np
true_1291 = np.zeros(len(descriptors))

# %%
for d in docs[1291]['descriptors']:
    if d.lower() in descriptors:
        true_1291[descriptors.index(d.lower())] = 1

# %%
# Out:
# 3.0

# %%
with open('articles.json', 'w') as f:
    json.dump(docs, f)
# Out:
# --------------------------------------------------------------
# TypeError                    Traceback (most recent call last)
# <ipython-input-77-6ae821b12797> in <module>()
#       1 with open('articles.json', 'w') as f:
# ----> 2     json.dump(docs, f)
#
# /usr/local/Cellar/python/2.7.13/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/__init__.pyc in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, encoding, default, sort_keys, **kw)
#     187     # could accelerate with writelines in some versions of Python, at
#     188     # a debuggability cost
# --> 189     for chunk in iterable:
#     190         fp.write(chunk)
#     191
#
# /usr/local/Cellar/python/2.7.13/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.pyc in _iterencode(o, _current_indent_level)
#     429             yield _floatstr(o)
#     430         elif isinstance(o, (list, tuple)):
# --> 431             for chunk in _iterencode_list(o, _current_indent_level):
#     432                 yield chunk
#     433         elif isinstance(o, dict):
#
# /usr/local/Cellar/python/2.7.13/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.pyc in _iterencode_list(lst, _current_indent_level)
#     330                 else:
#     331                     chunks = _iterencode(value, _current_indent_level)
# --> 332                 for chunk in chunks:
#     333                     yield chunk
#     334         if newline_indent is not None:
#
# /usr/local/Cellar/python/2.7.13/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.pyc in _iterencode_dict(dct, _current_indent_level)
#     406                 else:
#     407                     chunks = _iterencode(value, _current_indent_level)
# --> 408                 for chunk in chunks:
#     409                     yield chunk
#     410         if newline_indent is not None:
#
# /usr/local/Cellar/python/2.7.13/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.pyc in _iterencode(o, _current_indent_level)
#     440                     raise ValueError("Circular reference detected")
#     441                 markers[markerid] = o
# --> 442             o = _default(o)
#     443             for chunk in _iterencode(o, _current_indent_level):
#     444                 yield chunk
#
# /usr/local/Cellar/python/2.7.13/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.pyc in default(self, o)
#     182
#     183         """
# --> 184         raise TypeError(repr(o) + " is not JSON serializable")
#     185
#     186     def encode(self, o):
#
# TypeError: datetime.datetime(2016, 12, 31, 23, 0, 24) is not JSON serializable

# %%
long_desc
# Out:
# [u'amilies and family life?( food and agriculture organization, united nations (fao)0 far east, south and southeast asia and pa',
#  u'ews and news media newsdealers and newsstands newspaper guild, the (tng)d 9\ufffd national football league (nfl)s5 new h',
#  u'nited states economy united states foreign service i united states international relations c- united states merchan',
#  u'olitics and government5 political and economic integration poliomyelitis polisario front (front for liberation of saguia',
#  u'uspensions, dismissals and resignations sutton, percy e suzuki, zenko (prime min) 9 svoboda, ludvik (1895-1979) 080a',
#  u'customs (tariff),treaties,treaties,international relations,international relations,buddhism,treaties,international relations,buddhism',
#  u'suits and litigation,drug abuse and traffic,suits and litigation,threats and threatening messages,drug abuse and traffic,violence,threats and threatening messages,violence',
#  u'demonstrations and riots,united states politics and government,international relations,summit conferences',
#  u'politics and government,debating,united states politics and government,hiring and promotion',
#  u'international relations,treaties,united states international relations,arms control and limitation and disarmament',
#  u'real estate,banks and banking,freedom of speech and expression,entertainment and amusements',
#  u'immigration and refugees,united states politics and government,deportation,hispanic-americans',
#  u'politics and government,united states politics and government,election results,decisions and verdicts',
#  u'travel and vacations,executives and management,airlines and airplanes,company and organization profiles',
#  u'politics and government,travel and vacations,united states politics and government,states (us)',
#  u'space,space,space,news and news media,news and news media,news and news media,child custody and support,child custody and support,child custody and support,fuel,fuel,fuel',
#  u'debating,executives and management,supermarkets,executives and management,supermarkets,company and organization profiles',
#  u'suits and litigation,suits and litigation,politics and government,politics and government,debating,debating,united states politics and government,united states politics and government',
#  u'politics and government,budgets and budgeting,united states politics and government,states (us)',
#  u'immigration and refugees,crime and criminals,politics and government,united states politics and government',
#  u'music,music,music,music,music,antiques,antiques,antiques,fast food industry,antiques,athletics and sports,paleontology,athletics and sports,athletics and sports,athletics and sports,baseball,baseball,baseball,classical music,baseball',
#  u'television and radio programming,united states politics and government,suspensions, dismissals and resignations,impeachment',
#  u'travel and vacations,politics and government,books and literature,politics and government,books and literature,textiles',
#  u'athletics and sports,united states politics and government,freedom and human rights,freedom of speech and expression',
#  u'television and radio programming,baseball,athletics and sports,baseball,athletics and sports,football',
#  u'politics and government,television and radio programming,united states politics and government,primaries',
#  u'demonstrations and riots,palestinians,terrorism,palestinians,palestinians,terrorism,terrorism,palestinians,palestinians,terrorism,terrorism,palestinians,palestinians,terrorism,terrorism,palestinians,palestinians,terrorism,terrorism,palestinians,palestinians,terrorism,terrorism,vandalism,palestinians,terrorism,vandalism',
#  u'politics and government,taxation,budgets and budgeting,united states politics and government',
#  u'rescues,rescues,rescues,weather,weather,fires and firemen,fires and firemen,fires and firemen,seniority systems,seniority systems',
#  u'computers and the internet,mergers, acquisitions and divestitures,weddings and engagements,marriages',
#  u'teachers and school employees,hiring and promotion,employment agencies,education and schools',
#  u'executives and management,computers and the internet,finances,company and organization profiles',
#  u'ontainers and packaging conventions and conferences conventions and conferences conventions, national (us) c cook,',
#  u'children and youth,containers and packaging,police brutality and misconduct,homeless persons',
#  u'elevision tennessee valley authority and project (tva) trans world airlines (twa)@ twentieth century-fox film corp 2 tw',
#  u'renting and leasing,recordings (audio),mergers, acquisitions and divestitures,collectors and collections',
#  u'computers and the internet,stock options and purchase plans,company and organization profiles,indexers and indexing',
#  u'auctions,auctions,auctions,collectors and collections,collectors and collections,collectors and collections,marketing and merchandising,marketing and merchandising,marketing and merchandising,divorce, separations and annulments,divorce, separations and annulments,divorce, separations and annulments',
#  u'terms not available\n<m03,35,15,15>\n<d>\n<q>\nterms not available\n<x>\n<m03,35,15,15>\n<d>\n<q>\nterms not available\n<x>\n<m03,35,15,15>\n<d>\n<q>\n terms not available\n<x>\nterms not available',
#  u'editorials,international relations,summit conferences,armament, defense and military forces',
#  u'crime and criminals,crime and criminals,politics and government,politics and government,debating,debating,immigration and refugees,immigration and refugees',
#  u'united states politics and government,science and technology,reproduction (biological),heart',
#  u"the personal and political finances of the clintons and their business dealings in the 1980's, including their role in the whitewater development corporation",
#  u'politics and government,surgery and surgeons,united states politics and government,states (us)',
#  u'inorities (ethnic, racial, religious) ^ misleading and deceptive advertising mississippi missouri pacific rr co (m',
#  u'telephones and telecommunications,computers and the internet,reform and reorganization,company and organization profiles,telephones and telecommunications,stocks and bonds,computers and the internet',
#  u'politics and government,roads and traffic,united states politics and government,athletics and sports',
#  u'telephones and telecommunications,cellular telephones,company and organization profiles,auctions',
#  u'banks and banking,athletics and sports,marketing and merchandising,telephones and telecommunications',
#  u"terms not availablegillette declared itself victorious in its proxy fight with coniston partners. but the new york investment firm said it might challenge the outcome. coniston, which owns 5.8 percent of gillette's stock, had sought to elect four directors. gillette said it outpolled coniston, 52 percent to 48 percent. \n[\npage d1.\n]\n<p>\ntexaco filed suit against carl c. icahn, its largest shareholder, seeking to block him from pursuing a proxy battle to elect himself and four associates to the board. texaco said mr. icahn and his associates had used ''deceptive and manipulative means'' to try to make a profit at other shareholders' expense. \n[\nd1.\n]\n<p>\nthe trial of two former bankers ended in a hung jury while a third defendant was acquitted. a mistrial was declared in the trial on fraud charges of a former officer of continental illinois and a former penn square bank vice president. \n[\nd1.\n]\n<p>\nusg sued merrill lynch for its role in desert partners' hostile tender offer for usg. \n[\nd4.\n]\n<p>\nxerox introduced a major series of copiers, including a personal copier in the low end of the market. \n[\nd4.\n]\n<p>\namdahl introduced mainframes that it said are more powerful than any machines compatible with i.b.m.'s 3090 series. \n[\nd4.\n]\nthe economy\n<p>\n<p>\ndiscount store executives and consumer advocates complained that a supreme court ruling on monday would encourage some big, traditional merchants to put pressure on manufacturers to stop supplying discounters. but manufacturers doubted that the ruling would have a major impact. \n[\nd1.\n]\n sponsors of legislation that would make it easier for discounters to bring price-fixing cases against manufacturers and full-price retailers said the court's decision would probably improve the prospects for their bill. \n[\nd6.\n]\n<p>\ndemocrats moved to drop curbs on alaskan oil exports from the trade bill in the face of a threatened presidential veto. \n[\nd2.\n]\nmarkets\n<p>\n<p>\nthe s.e.c. will consider a plan that could ban all trading in a stock when important news about it is pending. one division supports the ban and another opposes it. \n[\nd1.\n]\n<p>\nstock prices spurted in late trading, lifting the dow jones industrial average by 15.09 points, to 2,058.36. on the big board, advancing issues outnumbered declining stocks, 897 to 580. \n[\nd8.\n]\n<p>\nprices of treasury bonds and notes staged a small rally in sleepy trading. activity was light because japanese financial markets were closed for a holiday. \n[\nd16.\n]\n<p>\nthe dollar rose narrowly in the u.s. and fell overseas. gold fell $2.10 on the comex, to $443.50 an ounce. \n[\nd15.\n]\n gold futures fell, despite the rally in oil prices. \n[\nd15.\n]\ninternational\n<p>\n<p>\noil prices steadied around the world as spokesmen for several oil-producing nations said they had not abandoned hope of cooperating with opec on steps to reduce output and bolster prices. \n[\nd2.\n]\n the saudi decision to block cutbacks drew an angry response from iran in the latest dispute between the two countries. \n[\na8.\n]\ntechnology\n<p>\n<p>\nmicroelectronics is changing the electric meter, enabling utilities to measure usage more frequently, even on demand. \n[\nd7.\n]\n<p>\na chocolate that stays firm at higher temperatures has been developed by a research firm. \n[\nd7.\n]\n<p>\na tether to keep champagne corks from flying away is being offered by a san francisco company. \n[\nd7.\n]\ntoday's columns\n<p>\n<p>\nmikhail s. gorbachev's attempt to depict his economic changes as a costless fix has left him in a precarious position. peter passell. economic scene. \n[\nd2.\n]\n<p>\nproponents of ''socially responsible investment'' say investors can prosper financially if they avoid companies whose products or policies violate their moral beliefs. but such investors were not spared the shock of october's market plunge. market place. \n[\nd8.\n]",
#  u'teachers and school employees,teachers and school employees,wages and salaries,hiring and promotion,principals (school),hiring and promotion',
#  u'rees and shrubs trenton state prison (nj): tribes and tribalism trotsky, leon (lev davidoch bronstein) (1879-1940)',
#  u'politics and government,customs (tariff),united states politics and government,freedom and human rights',
#  u'politics and government,politics and government,debating,politics and government,suits and litigation,states (us),debating,suits and litigation,debating,states (us),suits and litigation,states (us)',
#  u'television and radio programming,united states politics and government,television,states (us)',
#  u'drug abuse and traffic,united states politics and government,terrorism,united states politics and government,united states politics and government,terrorism,terrorism,international relations,united states politics and government,terrorism,international relations',
#  u'griculture agriculture, department of% 3 american hockey league (ahl)25 ahram, al (cairo) (newspaper) architects, americ',
#  u'television and radio programming,firearms,suspensions, dismissals and resignations,contests and prizes',
#  u'restaurants,television and radio programming,television,united states politics and government',
#  u'ata processing (computers) draft and recruitment, military s3 drapery and upholstery drivers licensing, training and test',
#  u'executives and management,executives and management,executives and management,frauds and swindling,executives and management,executives and management,frauds and swindling,frauds and swindling,frauds and swindling,wages and salaries,frauds and swindling,frauds and swindling,wages and salaries,theater,wages and salaries,wages and salaries,wages and salaries,wages and salaries,theater,theater,theater,stock options and purchase plans,theater,theater',
#  u'crime and criminals,politics and government,espionage,united states politics and government',
#  u'eoxyribonucleic acid (dna) dobrynin, anatoly fyodorovich (amb)08 4 documentary films and programs7 dodd, thomas j (190',
#  u'politics and government,debating,teachers and school employees,united states politics and government',
#  u'medicine and health,politics and government,suits and litigation,united states politics and government',
#  u'rack and field trade negotiations, office of the special representative for l 6 trademarks and trade names transconti',
#  u'teachers and school employees,divorce, separations and annulments,weddings and engagements,marriages',
#  u'computers and the internet,computers and the internet,computers and the internet,computers and the internet,computers and the internet,auctions,auctions,auctions,auctions,auctions,stocks and bonds,stocks and bonds,stocks and bonds,stocks and bonds,stocks and bonds,company and organization profiles,company and organization profiles,company and organization profiles,company and organization profiles,company and organization profiles',
#  u'mental health and disorders,federal aid (us),standards and standardization,recession and depression',
#  u'united states international relations united states international relations united states international relations',
#  u'executives and management,executives and management,automobiles,automobiles,company and organization profiles,company and organization profiles,vans,vans']
